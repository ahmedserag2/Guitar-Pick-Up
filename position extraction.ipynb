# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %%
#going right of the fretboard decreases x positions

df_correct = pd.read_csv('out_correct.csv')
df_correct.head()
# Out:
#    wrist_x  wrist_y  index_tip_x  index_tip_y  middle_tip_x  middle_tip_y  \
# 0      498      491          510          371           492           355
# 1      496      508          506          363           489           356
# 2      497      509          508          370           489           355
# 3      496      512          509          371           489           355
# 4      499      515          506          371           489           356
#
#    ring_tip_x  ring_tip_y  pinky_tip_x  pinky_tip_y
# 0         467         363          447          382
# 1         466         366          448          382
# 2         465         367          448          382
# 3         465         366          449          382
# 4         466         367          450          382

# %%
df_wrong = pd.read_csv('out_wrong.csv')
df_wrong.head()
# Out:
#    wrist_x  wrist_y  index_tip_x  index_tip_y  middle_tip_x  middle_tip_y  \
# 0      532      430          578          373           553           366
# 1      521      445          577          370           547           360
# 2      519      448          569          367           539           358
# 3      514      453          567          361           535           358
# 4      509      457          563          360           530           356
#
#    ring_tip_x  ring_tip_y  pinky_tip_x  pinky_tip_y
# 0         527         373          500          390
# 1         521         367          499          383
# 2         515         368          493          386
# 3         511         367          489          386
# 4         506         363          485          383

# %%
df_correct['wrist_x'].plot(),df_wrong['wrist_x'].plot()
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x24974f16648>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x24974f16648>)
