# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_mahmoud = pd.read_csv('left_hand.csv')
df_khaled = pd.read_csv('left_hand_khaled.csv')
# Out:
# C:\Users\ahmed\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (2,3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_khaled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12607 entries, 0 to 12606
# Data columns (total 68 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              12607 non-null  int64
#  1   frameNo         12607 non-null  int64
#  2   screen_width    12607 non-null  object
#  3   screen_height   12607 non-null  object
#  4   left_wrist_0x   12252 non-null  float64
#  5   left_wrist_0y   12252 non-null  float64
#  6   left_wrist_0z   12252 non-null  float64
#  7   left_thumb_1x   12252 non-null  float64
#  8   left_thumb_1y   12252 non-null  float64
#  9   left_thumb_1z   12252 non-null  float64
#  10  left_thumb_2x   12252 non-null  float64
#  11  left_thumb_2y   12252 non-null  float64
#  12  left_thumb_2z   12252 non-null  float64
#  13  left_thumb_3x   12252 non-null  float64
#  14  left_thumb_3y   12252 non-null  float64
#  15  left_thumb_3z   12252 non-null  float64
#  16  left_thumb_4x   12252 non-null  float64
# ...

# %%
plt.figure();
df_mahmoud.query("id == 3")['left_index_1x'].reset_index()['left_index_1x'].plot(label = "khaled"),df_mahmoud.query("id == 5")['left_index_1x'].reset_index()['left_index_1x'].plot(label = "zoair")
plt.legend()

# %%
df_khaled.query("id == 3")['left_index_1x'],df_mahmoud.query("id == 5")['left_index_1x']
# Out:
# (656    0.373904
#  657    0.373265
#  658    0.373127
#  659    0.372100
#  660    0.371796
#           ...
#  978    0.385160
#  979    0.381382
#  980    0.380924
#  981    0.381315
#  982    0.379677
#  Name: left_index_1x, Length: 327, dtype: float64,
#  2360         NaN
#  2361         NaN
#  2362         NaN
#  2363         NaN
#  2364         NaN
#            ...
#  2739    0.275503
#  2740    0.276590
#  2741    0.275227
#  2742    0.275769
#  2743    0.275015
#  Name: left_index_1x, Length: 384, dtype: float64)

# %%
df_label = pd.read_csv('left_hand_khaled_relabeled.csv')

# %%
len(df_label[['label','index_label']].query("label == 'wrong_placement' and index_label == 'correct'"))
# Out:
# 1577

# %%
len(df_label[['label','index_label']].query("label == 'wrong_placement' and index_label == 'correct'"))/len(df_label[['label','index_label']].query("label == 'wrong_placement'"))
#wrong_placement
# Out:
# 0.23526779054154856
